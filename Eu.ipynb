# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Eu = pd.read_csv("C:/Users/PRAVEENA/Downloads/migration/Eu migration.csv")
Eu
# Out:
#                     Country Name Country Code Indicator Name Indicator Code  \
# 0                          Aruba          ABW  Net migration    SM.POP.NETM
# 1    Africa Eastern and Southern          AFE  Net migration    SM.POP.NETM
# 2                    Afghanistan          AFG  Net migration    SM.POP.NETM
# 3     Africa Western and Central          AFW  Net migration    SM.POP.NETM
# 4                         Angola          AGO  Net migration    SM.POP.NETM
# ..                           ...          ...            ...            ...
# 261                       Kosovo          XKX  Net migration    SM.POP.NETM
# 262                  Yemen, Rep.          YEM  Net migration    SM.POP.NETM
# 263                 South Africa          ZAF  Net migration    SM.POP.NETM
# 264                       Zambia          ZMB  Net migration    SM.POP.NETM
# 265                     Zimbabwe          ZWE  Net migration    SM.POP.NETM
#
# ...

# %%
Eu['Country Name'].unique()
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
# ...

# %%
df = Eu.iloc[109:110,:]

# %%
df
# Out:
#     Country Name Country Code Indicator Name Indicator Code     1960  \
# 109        India          IND  Net migration    SM.POP.NETM  52264.0
#
#          1961      1962     1963    1964     1965  ...      2012      2013  \
# 109  114181.0  110398.0  48986.0  5837.0  19077.0  ... -180991.0 -236387.0
#
#          2014      2015     2016      2017      2018      2019     2020  \
# 109 -310694.0 -475094.0  68119.0 -219656.0 -561563.0 -593495.0 -34772.0
#
#          2021
# 109 -301970.0
#
# [1 rows x 66 columns]

# %%
file = df.drop(df.iloc[:, 4:54], axis=1)

# %%
file
# Out:
#     Country Name Country Code Indicator Name Indicator Code      2010  \
# 109        India          IND  Net migration    SM.POP.NETM -380087.0
#
#          2011      2012      2013      2014      2015     2016      2017  \
# 109 -244114.0 -180991.0 -236387.0 -310694.0 -475094.0  68119.0 -219656.0
#
#          2018      2019     2020      2021
# 109 -561563.0 -593495.0 -34772.0 -301970.0

# %%
file.to_csv('eu_clean.csv', index=False)

# %%
df.iloc[:,54:64]
# Out:
#          2010      2011      2012      2013      2014      2015     2016  \
# 109 -380087.0 -244114.0 -180991.0 -236387.0 -310694.0 -475094.0  68119.0
#
#          2017      2018      2019
# 109 -219656.0 -561563.0 -593495.0
